# %%
! pip install beautifulsoup4
! pip install parser
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement parser (from versions: none)
# ERROR: No matching distribution found for parser

# %%
df.to_csv('top250movies.csv')

# %%
pip install beautifulsoup4 lxml
# Out:
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#     --------------------------------------- 0.1/3.8 MB 252.2 kB/s eta 0:00:15
#     --------------------------------------- 0.1/3.8 MB 252.2 kB/s eta 0:00:15
#     --------------------------------------- 0.1/3.8 MB 241.3 kB/s eta 0:00:16
#    - -------------------------------------- 0.1/3.8 MB 267.9 kB/s eta 0:00:14
#    - -------------------------------------- 0.1/3.8 MB 267.9 kB/s eta 0:00:14
#    - -------------------------------------- 0.2/3.8 MB 339.7 kB/s eta 0:00:11
#    - -------------------------------------- 0.2/3.8 MB 339.7 kB/s eta 0:00:11
#    - -------------------------------------- 0.2/3.8 MB 339.7 kB/s eta 0:00:11
# ...

# %%
from bs4 import BeautifulSoup

html_doc = '''
          <html lang="en">
          <head>
         <title>Movie List — The Movie Database (TMDb)</title>
         <!-- Other meta tags and styles -->
         </head>
   <body>
      <div id="main" class="content">
         <!-- First Movie -->
         <div class="movie_header">
            <h2 class="title">Avengers: Infinity War</h2>
            <span class="release">April 25, 2018</span>
         </div>
         <div class="overview">
            <h3>Overview</h3>
            <p>As the Avengers and their allies have continued to protect the world from threats too large for any one hero to handle...</p>
         </div>

         <!-- Second Movie -->
         <div class="movie_header">
            <h2 class="title">The Dark Knight</h2>
            <span class="release">July 18, 2008</span>
         </div>
         <div class="overview">
            <h3>Overview</h3>
            <p>When the menace known as the Joker emerges from his mysterious past, he wreaks havoc and chaos on the people of Gotham...</p>
         </div>

         <!-- Third Movie -->
         <div class="movie_header">
            <h2 class="title">Inception</h2>
            <span class="release">July 16, 2010</span>
         </div>
         <div class="overview">
            <h3>Overview</h3>
            <p>A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea...</p>
         </div>

         <!-- Other content such as cast, crew, reviews, etc. -->
      </div>
   </body>
</html>
'''
         
soup = BeautifulSoup(html_doc,"html.parser") #if we use xml content then we use xml.parser
print(soup)
# Out:
# <html lang="en">
# <head>
# <title>Movie List — The Movie Database (TMDb)</title>
# <!-- Other meta tags and styles -->
# </head>
# <body>
# <div class="content" id="main">
# <!-- First Movie -->
# <div class="movie_header">
# <h2 class="title">Avengers: Infinity War</h2>
# <span class="release">April 25, 2018</span>
# </div>
# <div class="overview">
# <h3>Overview</h3>
# <p>As the Avengers and their allies have continued to protect the world from threats too large for any one hero to handle...</p>
# </div>
# <!-- Second Movie -->
# <div class="movie_header">
# <h2 class="title">The Dark Knight</h2>
# <span class="release">July 18, 2008</span>
# </div>
# <div class="overview">
# <h3>Overview</h3>
# <p>When the menace known as the Joker emerges from his mysterious past, he wreaks havoc and chaos on the people of Gotham...</p>
# </div>
# <!-- Third Movie -->
# <div class="movie_header">
# <h2 class="title">Inception</h2>
# <span class="release">July 16, 2010</span>
# </div>
# ...

# %%
title_tag = soup.find("title")
print(title_tag.text) #this will return tag without tags
# Out:
# Movie List — The Movie Database (TMDb)

# %%
div_tag = soup.find_all('div',id_="main")
for i in div_tag:
    print(i.text) #there is come all extra thing which we dont need to how identify

# %%
div_tag = soup.find_all('div', class_="movie_header")
for i in div_tag:
    print(i.text) #there is come all extra thing which we dont need to how identify
# Out:
# Avengers: Infinity War
# April 25, 2018
#
#
# The Dark Knight
# July 18, 2008
#
#
# Inception
# July 16, 2010

# %%
div_tag = soup.find("div",class_="movie_header")
print(div_tag.text) #there is come all extra thing which we dont need to how identify
# Out:
# Avengers: Infinity War
# April 25, 2018

# %%
! pip install requests

# %%
import requests

responce = requests.get('https://www.imdb.com/chart/top/', headers ={"User-Agent":"Mozilla/5.0"})

# %%
responce
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(responce.text,'html.parser')

# %%
data = soup.find('script',id='__NEXT_DATA__')

# %%
data = str(data.text)
data = data.replace('false','False')
data = data.replace('true','True')
data = data.replace('null','None')
print(type(data))
data = eval(data)
# Out:
# <class 'str'>

# %%
data_fetched = data['props']['pageProps']['pageData']['chartTitles']['edges']

# %%
len(data_fetched)
# Out:
# 250

# %%
movie_name = data_fetched[0]['node']['titleText']['text']
movie_name
# Out:
# 'The Shawshank Redemption'

# %%
year = data_fetched[0]['node']['releaseYear']['year']
year
# Out:
# 1994

# %%
ratings = data_fetched[0]['node']['ratingsSummary']['aggregateRating']
ratings
# Out:
# 9.3

# %%
l1=[]
l2=[]
l3=[]
for i in range(len(data_fetched)):
    movie_name = data_fetched[i]['node']['titleText']['text']
    year = data_fetched[i]['node']['releaseYear']['year']
    rating = data_fetched[i]['node']['ratingsSummary']['aggregateRating']
    l1.append(movie_name)
    l2.append(year)
    l3.append(rating)
print("*"*100)
print("Movie Name is",l1)
print("*"*100)
print("Year is",l2)
print("*"*100)
print("Rating is",l3)
print("*"*100)
# Out:
# ****************************************************************************************************
# ...

# %%
import pandas as pd
d = {"movie name":l1,"year":l2,"ratings":l3}
df = pd.DataFrame(d)
df
# Out:
#                    movie name  year  ratings
# 0    The Shawshank Redemption  1994      9.3
# 1               The Godfather  1972      9.2
# 2             The Dark Knight  2008      9.0
# 3      The Godfather: Part II  1974      9.0
# 4                12 Angry Men  1957      9.0
# ..                        ...   ...      ...
# 245            Cool Hand Luke  1967      8.1
# 246     It Happened One Night  1934      8.1
# 247        Gangs of Wasseypur  2012      8.2
# 248                  Drishyam  2015      8.2
# 249              Paris, Texas  1984      8.1
#
# [250 rows x 3 columns]

# %%
df.to_csv('top250movies.csv')
